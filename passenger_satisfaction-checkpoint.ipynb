# %% [markdown]
# # Problem Statement

# %% [markdown]
# This dataset is an US Airline passenger satisfaction survey. The main aim of this problem statement is to predict whether the customer is satisfied with his/her airplane experience or not. This problem comes under classification and this classification is done on the basis of passenger information and ratings given by him/her.

# %% [markdown]
# # Performance Metric

# %% [markdown]
# The data set is balanced. The metrics that can be used are  <br>
#
# 1.Accuracy <br>
# 2.ROC curve <br>
# 3.Confusion matrix <br>
#
# I would like to evaluate my model based on Accuracy.

# %% [markdown]
# # Code

# %% [markdown]
# Now I'll be importing the necessary libraries to perform Exploratory Data Analysis and Then I'll be loading the data.

# %%
import pandas as p
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

df2=p.read_csv(r"C:\Users\sai\Documents\Copy of satisfaction_2015.csv")

# %%
df2.shape
# Out:
# (129880, 24)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
# id                                   129880 non-null int64
# satisfaction_v2                      129880 non-null object
# Gender                               129880 non-null object
# Customer Type                        129880 non-null object
# Age                                  129880 non-null int64
# Type of Travel                       129880 non-null object
# Class                                129880 non-null object
# Flight Distance                      129880 non-null int64
# Inflight wifi service                129880 non-null int64
# Departure/Arrival time convenient    129880 non-null int64
# Ease of Online booking               129880 non-null int64
# Gate location                        129880 non-null int64
# Food and drink                       129880 non-null int64
# Online boarding                      129880 non-null int64
# ...

# %% [markdown]
# So The dataset contains 129880 rows and 24 columns. And I've also displayes each types.

# %%
df2.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  129880.000000  129880.000000    129880.000000          129880.000000
# mean    64940.500000      39.427957      1190.316392               2.728696
# std     37493.270818      15.119360       997.452477               1.329340
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32470.750000      27.000000       414.000000               2.000000
# 50%     64940.500000      40.000000       844.000000               3.000000
# 75%     97410.250000      51.000000      1744.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      129880.000000           129880.000000
# mean                            3.057599                2.756876
# std                             1.526741                1.401740
# ...

# %%
sb.factorplot(x='satisfaction_v2',kind='count',size=5, data=df2);
plt.rcParams.update({'font.size': 15})
plt.show()
df2['satisfaction_v2'].value_counts(1)*100
# Out:
# neutral or dissatisfied    56.553742
# satisfied                  43.446258
# Name: satisfaction_v2, dtype: float64

# %% [markdown]
# # Some Useful Functions

# %% [markdown]
# Here I've defined a function for histogram for future uses.

# %%
def hist(feature, x , y):
    counts, bin_edges = np.histogram(feature, bins=10, density = True)
    pdf = counts/(sum(counts))
    print(pdf);
    print(bin_edges)

    #compute CDF
    cdf = np.cumsum(pdf)
    plt.plot(bin_edges[1:],pdf)
    plt.plot(bin_edges[1:], cdf)
    plt.gca().legend(('pdf','cdf'))
    plt.xlabel(x)
    plt.ylabel(y)

    plt.show();

# %% [markdown]
# # Gender
# ## Type - Categorical

# %%
df2.Gender.value_counts()
# Out:
# Female    65899
# Male      63981
# Name: Gender, dtype: int64

# %%
df2.Gender.value_counts(1)*100
# Out:
# Female    50.738374
# Male      49.261626
# Name: Gender, dtype: float64

# %% [markdown]
# Here I've displayed the number of rows with each <i>female</i> and <i>male</i> values. The second cell gives the percentages of <i>female</i> and <i>male</i> values.

# %% [markdown]
# # Age
# ## Type - Numerical

# %%
df2.Age.describe()
# Out:
# count    129880.000000
# mean         39.427957
# std          15.119360
# min           7.000000
# 25%          27.000000
# 50%          40.000000
# 75%          51.000000
# max          85.000000
# Name: Age, dtype: float64

# %%
print(df2.Age.unique())
print(len(df2.Age.unique()))
# Out:
# [56 49 55 36 15 51 26 37 65 18 22 40 14 45 53 35 57 25 10 60 17 68 28 47
#  52 34 13 50 64 39 70  8 32 21 67 62 69 63 12 59 27 20 61 30 66 46 54 38
#  11  7 24 33  9 23 31 58 19 42 16 29 43 48 44 41 72 71 80 77 85 78 75 79
#  74 73 76]
# 75

# %% [markdown]
# Here I've displayed all the unique values that <i>"Age"</i> feature has taken and then printing the number of unique values

# %%
hist(df2['Age'],"Age(in years)",'probability')
# Out:
# [0.04973822 0.09571143 0.16930243 0.15006929 0.16931783 0.16556052
#  0.13170619 0.0552741  0.01154142 0.00177856]
# [ 7.  14.8 22.6 30.4 38.2 46.  53.8 61.6 69.4 77.2 85. ]

# %% [markdown]
# ## observation 2:

# %% [markdown]
# 1. this feature can be used as the difference between both classes is large, with a condition that these features needs to be classified with respect to trends i.e.
#    * age < 29 and age > 61 --> majority of these passengers are satisfied
#    * age > 29 and age < 61 --> majority of these passengers are neutral or dissatisfied
# 2. There are No outliers or Missing values

# %%
bins = [0, 29,61, 100]
labels = [0,1,2]
df2['binned'] = p.cut(df2['Age'], bins=bins, labels=labels)
df2.head()
# Out:
#        id satisfaction_v2  Gender      Customer Type  Age   Type of Travel  \
# 0  117135       satisfied    Male  disloyal Customer   56  Personal Travel
# 1   72091       satisfied    Male  disloyal Customer   49  Personal Travel
# 2   29663       satisfied    Male  disloyal Customer   55  Personal Travel
# 3   81849       satisfied  Female  disloyal Customer   36  Personal Travel
# 4   83693       satisfied    Male  disloyal Customer   55  Personal Travel
#
#   Class  Flight Distance  Inflight wifi service  \
# 0   Eco              369                      0
# 1   Eco             2486                      0
# 2   Eco             1448                      0
# 3   Eco             1501                      0
# 4   Eco              577                      0
#
#    Departure/Arrival time convenient   ...    Inflight entertainment  \
# 0                                  2   ...                         3
# 1                                  2   ...                         2
# ...

# %% [markdown]
# I've binned the age column into 3 bins, namely 0 , 1  and 2. <br>
# After adding the column 'binned' which takes labels 0 or 1 or 2 , If we print the dataset, It looks something like the above.

# %% [markdown]
# Now we will plot and see how they are

# %%
sb.factorplot(col='binned' ,x ='satisfaction_v2',kind='count',size=5, data=df2);

# %% [markdown]
# ## Note :
# we have segregated people of different ages into three classes
#     * 0-29 --> 0
#     * 30-61 --> 1
#     * 61-100 --> 2
#
#
# there are more adults who are neutral and dissatisfied.

# %% [markdown]
# # Type of travel
# ## Type - Categorical

# %% [markdown]
# Here I've displayed the number of rows with each <i>Business travel</i> and <i>Personal Travel</i> values. The second cell gives the percentages of <i>Business travel</i> and <i>Personal Travel</i> values.

# %%
df2['Type of Travel'].value_counts()
# Out:
# Business travel    89693
# Personal Travel    40187
# Name: Type of Travel, dtype: int64

# %%
df2['Type of Travel'].value_counts(1)*100
# Out:
# Business travel    69.058362
# Personal Travel    30.941638
# Name: Type of Travel, dtype: float64

# %%
ax = sb.factorplot(x='satisfaction_v2' ,col ='Type of Travel',kind='count',size=5, data=df2,legend_out = True);
plt.rcParams.update({'font.size': 15})
plt.show()

# %%
p.crosstab([df2.Gender, df2.satisfaction_v2],df2['Type of Travel'], margins=True)
# Out:
# Type of Travel                  Business travel  Personal Travel     All
# Gender satisfaction_v2
# Female neutral or dissatisfied            19571            18059   37630
#        satisfied                          26223             2046   28269
# Male   neutral or dissatisfied            17766            18056   35822
#        satisfied                          26133             2026   28159
# All                                       89693            40187  129880

# %% [markdown]
# almost 93% (92.78%) of the satisfied customers travelled in business class

# %% [markdown]
# # Class
# ## Type - Categorical

# %%
df2.Class.describe()
# Out:
# count       129880
# unique           3
# top       Business
# freq         62160
# Name: Class, dtype: object

# %%
df2.Class.value_counts()
# Out:
# Business    62160
# Eco         58309
# Eco Plus     9411
# Name: Class, dtype: int64

# %%
ax = sb.factorplot(x='satisfaction_v2' ,col ='Class',kind='count',size=5, data=df2,legend_out = True);
plt.rcParams.update({'font.size': 15})
plt.show()
print("The percentage of each class is \n" + str(df2.Class.value_counts(1)*100))
# Out:
# The percentage of each class is
# Business    47.859563
# Eco         44.894518
# Eco Plus     7.245919
# Name: Class, dtype: float64

# %%
p.crosstab([df2.Gender, df2.satisfaction_v2],df2.Class, margins=True)
# Out:
# Class                           Business    Eco  Eco Plus     All
# Gender satisfaction_v2
# Female neutral or dissatisfied      9663  24171      3796   37630
#        satisfied                   21600   5499      1170   28269
# Male   neutral or dissatisfied      9331  23195      3296   35822
#        satisfied                   21566   5444      1149   28159
# All                                62160  58309      9411  129880

# %% [markdown]
# ## observation 3:
# almost 76.5% of the satisfied customers belong to business class and 19.3% of satisfied customers are from economy class.

# %% [markdown]
# Now I'm changing the column names for my convenience. <i>'Flight Distance'</i> is replaced by <i>'FDistance'</i> and so on.

# %%
df2 = df2.rename(columns={'Flight Distance': 'FDistance'})
df2 = df2.rename(columns={'Type of Travel': 'Travel_type'})
df2 = df2.rename(columns={'Customer Type': 'Cus_Type'})

# %%
df2 = df2.rename(columns={'Inflight wifi service': 'Inflight_wifi_service'})
df2 = df2.rename(columns={'Departure/Arrival time convenient' : 'DA_time_conv'})
df2 = df2.rename(columns={'Ease of Online booking' : 'Ease'})
df2 = df2.rename(columns={'Gate location' : 'Gate_location'})
df2 = df2.rename(columns={'Food and drink' : 'Food_and_drink'})
df2 = df2.rename(columns={'Online boarding' : 'Online_boarding'})
df2 = df2.rename(columns={'Seat comfort' : 'Seat_comfort'})
df2 = df2.rename(columns={'Inflight entertainment' : 'Inflight_entertainment'})
df2 = df2.rename(columns={'On-board service' : 'Onboard_service'})
df2 = df2.rename(columns={'Leg room service' : 'Leg_room_service'})
df2 = df2.rename(columns={'Baggage handling' : 'Baggage_handling'})
df2 = df2.rename(columns={'Checkin service' : 'Checkin_service'})
df2 = df2.rename(columns={'Inflight service' : 'Inflight_service'})
df2 = df2.rename(columns={'Departure Delay in Minutes' : 'Departure_Delay_in_Minutes'})
df2 = df2.rename(columns={'Arrival Delay in Minutes' : 'Arrival_Delay_in_Minutes'})

# %% [markdown]
# # Customer_Type
# ## Type - Categorical

# %%
df2.Cus_Type.describe()
# Out:
# count             129880
# unique                 2
# top       Loyal Customer
# freq              106100
# Name: Cus_Type, dtype: object

# %%
df2.Cus_Type.value_counts()
# Out:
# Loyal Customer       106100
# disloyal Customer     23780
# Name: Cus_Type, dtype: int64

# %%
ax = sb.factorplot(x='Cus_Type' ,col ='Travel_type',kind='count',size=5, data=df2,legend_out = True);
plt.rcParams.update({'font.size': 15})
plt.show()

# %%
p.crosstab([df2.satisfaction_v2, df2.Travel_type],df2['Cus_Type'], margins=True)
# Out:
# Cus_Type                                 Loyal Customer  disloyal Customer  \
# satisfaction_v2         Travel_type
# neutral or dissatisfied Business travel           19426              17911
#                         Personal Travel           35946                169
# satisfied               Business travel           46688               5668
#                         Personal Travel            4040                 32
# All                                              106100              23780
#
# Cus_Type                                    All
# satisfaction_v2         Travel_type
# neutral or dissatisfied Business travel   37337
#                         Personal Travel   36115
# satisfied               Business travel   52356
#                         Personal Travel    4072
# All                                      129880

# %% [markdown]
# # Observation 4:
#     there are more loyal customers who are neutral or dissatisfied.
#     89.2% of satisfied people who go for business purpose are loyal.
#     99.2% of satisfied people who go for personal travel are loyal.

# %%
p.crosstab([df2.satisfaction_v2, df2.Class],df2['Cus_Type'], margins=True)
# Out:
# Cus_Type                          Loyal Customer  disloyal Customer     All
# satisfaction_v2         Class
# neutral or dissatisfied Business           13425               5569   18994
#                         Eco                35697              11669   47366
#                         Eco Plus            6250                842    7092
# satisfied               Business           39504               3662   43166
#                         Eco                 8978               1965   10943
#                         Eco Plus            2246                 73    2319
# All                                       106100              23780  129880

# %% [markdown]
#     * around 92% of the loyal customers who took business class  are satisfied.
#     * around 82% of the loyal customers who took economy class  are satisfied.
#     * around 97% of the loyal customers who took eco plus class  are satisfied.

# %% [markdown]
# Here, I'm going to do feature engineering based on the above results.
# 1. I am trying to build a feature with name <i> 'loy' </i> where in, if a person is Loyal and either travelling by Eco or Business or Eco Plus, The customer is considered as satisfied else the customer is dissatisfied.
# 2. I am trying to build another feature with name <i> 'tt' </i> where in, if a person is Loyal and either travelling by Business Travel or Personal Travel, The customer is considered as satisfied else the customer is dissatisfied.

# %%
def loy(x,y):
    if (x=='Loyal Customer' and (y== 'Eco' or y== 'Business' or y== 'Eco Plus')) :
        return(1)
    else:
        return(0)

# %%
df2['loy'] = list(map(loy,df2['Cus_Type'],df2['Class']))

# %%
def tt(x,y):
    if (x=='Loyal Customer' and (y== 'Business Travel' or y== 'Personal Travel')) :
        return(1)
    else:
        return(0)

# %%
df2['tt'] = list(map(tt,df2['Cus_Type'],df2['Travel_type']))

# %%
df2.head()
# Out:
#        id satisfaction_v2  Gender           Cus_Type  Age      Travel_type  \
# 0  117135       satisfied    Male  disloyal Customer   56  Personal Travel
# 1   72091       satisfied    Male  disloyal Customer   49  Personal Travel
# 2   29663       satisfied    Male  disloyal Customer   55  Personal Travel
# 3   81849       satisfied  Female  disloyal Customer   36  Personal Travel
# 4   83693       satisfied    Male  disloyal Customer   55  Personal Travel
#
#   Class  FDistance  Inflight_wifi_service  DA_time_conv ...  Leg_room_service  \
# 0   Eco        369                      0             2 ...                 5
# 1   Eco       2486                      0             2 ...                 1
# 2   Eco       1448                      0             3 ...                 5
# 3   Eco       1501                      0             4 ...                 4
# 4   Eco        577                      0             5 ...                 4
#
# ...

# %%
df2.columns.values
# Out:
# array(['id', 'satisfaction_v2', 'Gender', 'Cus_Type', 'Age',
#        'Travel_type', 'Class', 'FDistance', 'Inflight_wifi_service',
#        'DA_time_conv', 'Ease', 'Gate_location', 'Food_and_drink',
#        'Online_boarding', 'Seat_comfort', 'Inflight_entertainment',
#        'Onboard_service', 'Leg_room_service', 'Baggage_handling',
#        'Checkin_service', 'Inflight_service', 'Cleanliness',
#        'Departure_Delay_in_Minutes', 'Arrival_Delay_in_Minutes', 'binned',
#        'loy', 'tt'], dtype=object)

# %% [markdown]
# Now, I want to find the covariance between each feature with respect to other feature in the given dataset, just to know whether any two features have high covariance or not.

# %%
df3 = df2.cov()

# %%
df_norm = (df3 - df3.mean()) / (df3.max() - df3.min())

# %%
df_norm
# Out:
#                                   id       Age  FDistance  \
# id                          0.952227  0.944690   0.939044
# Age                        -0.047729 -0.034911  -0.060502
# FDistance                  -0.045196  0.075384   0.217629
# Inflight_wifi_service      -0.047738 -0.054715  -0.060919
# DA_time_conv               -0.047737 -0.054669  -0.060930
# Ease                       -0.047736 -0.054702  -0.060896
# Gate_location              -0.047737 -0.054744  -0.060920
# Food_and_drink             -0.047737 -0.054703  -0.060900
# Online_boarding            -0.047735 -0.054375  -0.060841
# Seat_comfort               -0.047735 -0.054468  -0.060864
# Inflight_entertainment     -0.047737 -0.054612  -0.060873
# Onboard_service            -0.047735 -0.054647  -0.060882
# Leg_room_service           -0.047735 -0.054675  -0.060872
# Baggage_handling           -0.047734 -0.054817  -0.060900
# Checkin_service            -0.047734 -0.054687  -0.060896
# ...

# %%
 df2.columns[df2.isna().any()].tolist()
# Out:
# ['Arrival_Delay_in_Minutes']

# %% [markdown]
# ## observation 8:

# %% [markdown]
#  So clearly, we have got null values in arrival delay in minutes column. so, instead of imputing I'm deleting those entire rows as it doesn't make any sense to impute dummy values and plot them for analysis.

# %% [markdown]
# # Arrival_Delay_in_Minutes
# ## Type - Numerical

# %% [markdown]
# ### 1. Null values removal by deleting the rows

# %%
 df2.columns[df2.isna().any()].tolist()
# Out:
# ['Arrival_Delay_in_Minutes']

# %%
df2 = df2[np.isfinite(df2['Arrival_Delay_in_Minutes'])]

# %%
df2.columns[df2.isna().any()].tolist()
# Out:
# []

# %% [markdown]
# So there are no nan values in the dataset now

# %%
df2.shape
# Out:
# (129487, 27)

# %% [markdown]
# This is the new shape of dataset that we got after removing the rows which contain null values in any of the column.

# %%
p.crosstab([df2['Cus_Type'],df2.satisfaction_v2], df2.DA_time_conv , margins=True)
# Out:
# DA_time_conv                                  0      1      2      3      4  \
# Cus_Type          satisfaction_v2
# Loyal Customer    neutral or dissatisfied  1199   6805   7325   8088  16594
#                   satisfied                1341   9387   9301   9389  10764
# disloyal Customer neutral or dissatisfied  2255   3060   4596   4407   2837
#                   satisfied                1869     99    256    418   1591
# All                                        6664  19351  21478  22302  31786
#
# DA_time_conv                                   5     All
# Cus_Type          satisfaction_v2
# Loyal Customer    neutral or dissatisfied  15188   55199
#                   satisfied                10392   50574
# disloyal Customer neutral or dissatisfied    871   18026
#                   satisfied                 1455    5688
# All                                        27906  129487

# %% [markdown]
# Clearly there are more loyal customers who were convenient with departure and arrival delays

# %% [markdown]
# # Converting categorical into numerical values

# %% [markdown]
# We need to convert each categorical values into numerical values

# %%
def satisfaction(x):
    if x=='satisfied' :
        return 1 
    else :
        return 0

# %%
actualScore = df2['satisfaction_v2']
satunsat = actualScore.map(satisfaction) 
df2['satisfaction_v2'] = satunsat
print("Number of data points in our data", df2.shape)
df2.head(10)
# Out:
# Number of data points in our data (129487, 27)
# C:\ProgramData\Anaconda31\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        id  satisfaction_v2  Gender           Cus_Type  Age      Travel_type  \
# 0  117135                1    Male  disloyal Customer   56  Personal Travel
# 1   72091                1    Male  disloyal Customer   49  Personal Travel
# 2   29663                1    Male  disloyal Customer   55  Personal Travel
# 3   81849                1  Female  disloyal Customer   36  Personal Travel
# 4   83693                1    Male  disloyal Customer   55  Personal Travel
# ...

# %%
def gender(x):
    if x=='Male' :
        return 1 
    else :
        return 0

# %%
actualScore = df2['Gender']
satunsat = actualScore.map(gender) 
df2['Gender'] = satunsat
print("Number of data points in our data", df2.shape)
df2.head(10)
# Out:
# Number of data points in our data (129487, 27)
# C:\ProgramData\Anaconda31\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        id  satisfaction_v2  Gender           Cus_Type  Age      Travel_type  \
# 0  117135                1       1  disloyal Customer   56  Personal Travel
# 1   72091                1       1  disloyal Customer   49  Personal Travel
# 2   29663                1       1  disloyal Customer   55  Personal Travel
# 3   81849                1       0  disloyal Customer   36  Personal Travel
# 4   83693                1       1  disloyal Customer   55  Personal Travel
# ...

# %%
def cus_type(x):
    if x=='Loyal Customer' :
        return 1 
    else :
        return 0

# %%
actualScore = df2['Cus_Type']
satunsat = actualScore.map(cus_type) 
df2['Cus_Type'] = satunsat
print("Number of data points in our data", df2.shape)
df2.head(10)
# Out:
# Number of data points in our data (129487, 27)
# C:\ProgramData\Anaconda31\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        id  satisfaction_v2  Gender  Cus_Type  Age      Travel_type Class  \
# 0  117135                1       1         0   56  Personal Travel   Eco
# 1   72091                1       1         0   49  Personal Travel   Eco
# 2   29663                1       1         0   55  Personal Travel   Eco
# 3   81849                1       0         0   36  Personal Travel   Eco
# 4   83693                1       1         0   55  Personal Travel   Eco
# ...

# %%
def travel_type(x):
    if x=='Personal Travel' :
        return 1 
    else :
        return 0

# %%
actualScore = df2['Travel_type']
satunsat = actualScore.map(travel_type) 
df2['Travel_type'] = satunsat
print("Number of data points in our data", df2.shape)
df2.head(10)
# Out:
# Number of data points in our data (129487, 27)
# C:\ProgramData\Anaconda31\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        id  satisfaction_v2  Gender  Cus_Type  Age  Travel_type Class  \
# 0  117135                1       1         0   56            1   Eco
# 1   72091                1       1         0   49            1   Eco
# 2   29663                1       1         0   55            1   Eco
# 3   81849                1       0         0   36            1   Eco
# 4   83693                1       1         0   55            1   Eco
# 5  129488                0       0         0   15            1   Eco
# ...

# %%
def Class(x):
    if x=='Eco' :
        return 2
    elif x=='Eco Plus' :
        return 1
    else :
        return 0

# %%
actualScore = df2['Class']
satunsat = actualScore.map(Class) 
df2['Class'] = satunsat
print("Number of data points in our data", df2.shape)
df2.head(10)
# Out:
# Number of data points in our data (129487, 27)
# C:\ProgramData\Anaconda31\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        id  satisfaction_v2  Gender  Cus_Type  Age  Travel_type  Class  \
# 0  117135                1       1         0   56            1      2
# 1   72091                1       1         0   49            1      2
# 2   29663                1       1         0   55            1      2
# 3   81849                1       0         0   36            1      2
# 4   83693                1       1         0   55            1      2
# 5  129488                0       0         0   15            1      2
# ...

# %% [markdown]
# Now I'm going to delete the categorical features, as we have already created numerical features for them.

# %%
del df2['Travel_type']
del df2['Age']
del df2['Cus_Type']
del df2['Class']

# %%
del df2['Gender']

# %%
df2.head()
# Out:
#        id  satisfaction_v2  FDistance  Inflight_wifi_service  DA_time_conv  \
# 0  117135                1        369                      0             2
# 1   72091                1       2486                      0             2
# 2   29663                1       1448                      0             3
# 3   81849                1       1501                      0             4
# 4   83693                1        577                      0             5
#
#    Ease  Gate_location  Food_and_drink  Online_boarding  Seat_comfort ...  \
# 0     0              4               3                0             3 ...
# 1     1              4               2                1             3 ...
# 2     0              4               3                0             3 ...
# 3     0              3               4                0             4 ...
# 4     0              3               3                5             3 ...
#
# ...

# %% [markdown]
# # Train-CV-Test splitting

# %% [markdown]
# Now I'm importing necessary libraries and making necessary changes to my dataset to perform train-test split. <br>
# I'm separating the 'satisfaction_v2' column from the data set and giving it to the train_test_split() function. I'm repeating this splitting again as we need to get train and cross validation data i. e. <br>
# df2 = train data + cross validate data + test data (i.e. total data set) <br>
# xtr = train data + cross validate data <br>
# xtrain = train data <br>
# xcv = cross validate data

# %%
from sklearn.model_selection import train_test_split

# %%
target = df2['satisfaction_v2'].copy()

# %%
df2 = df2.drop(['satisfaction_v2','id','Departure_Delay_in_Minutes','Arrival_Delay_in_Minutes','Gate_location'],axis=1)

# %%
xtr, xtest, ytr, ytest = train_test_split(df2, target ,train_size=0.8, test_size=0.2)

# %%
xtrain, xcv, ytrain, ycv = train_test_split(xtr, ytr ,train_size=0.8, test_size=0.2)

# %%
print("train shape : "+ str(xtr.shape))
print("training shape : "+ str(xtrain.shape))
print("cv shape : "+ str(xcv.shape))
print("test shape : "+ str(xtest.shape))
# Out:
# train shape : (103589, 17)
# training shape : (82871, 17)
# cv shape : (20718, 17)
# test shape : (25898, 17)

# %% [markdown]
# # Random Forest Model

# %% [markdown]
#  Now I'm importing necessary libraries to build a model. I've also defined a function <i>"cm"</i> which will print my confusion matrix.

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score,f1_score,precision_score,accuracy_score

# %%
def cm(df_cm):  
    """confusion_matrix_Plot = confusion_matrix(y_test,pred1)
    heatmap = sns.heatmap(confusion_matrix_Plot, annot=True,cmap="plasma", fmt="d")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right')
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    tn, fp, fn, tp = df_cm.ravel()"""
    #df_cm = df_cm.astype('float') / df_cm.sum(axis=0)[1:, np.newaxis]
    sb.set(context='notebook',palette='deep')#for label size
    #for plot #https://matplotlib.org/examples/color/colormaps_reference.html
    sb.heatmap(df_cm, annot=True,cmap="Greens",xticklabels=["negative","positive"], yticklabels=["negative","positive"], fmt='g')
    plt.title('Confusion Matrix',fontsize=18)
    plt.xlabel('Predicted label',fontsize=15)
    plt.ylabel('True label',fontsize=15)
    plt.show()
    tn, fp, fn, tp = df_cm.ravel()
    print(" True Negative = "+str(tn)+"\n False positive = "+str(fp)+"\n False Negative = "+str(fn)+"\n True Positive = "+str(tp))

# %% [markdown]
# I'm building my model using Random Forest Classifier but with more number of estimators. Here alpha indicates number of estimators.

# %%
alpha = [50,100,150,200,250,300,350,400]
max_depth = [5, 10]
accuracy_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, max_depth=j)
        clf.fit(xtrain,ytrain)
        #sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        #sig_clf.fit(X_train_,y_train_)
        pred = clf.predict(xcv) 
        #sig_clf_probs = sig_clf.predict_proba(X_cv_)
        accuracy_array.append(accuracy_score(ycv, pred))
        df_cm = confusion_matrix(ycv,pred)
        cm(df_cm)
 

print(accuracy_array)
best_alpha = np.argmax(accuracy_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)],max_depth=max_depth[int(best_alpha%2)])
clf.fit(xtrain,ytrain)


predict_y = clf.predict(xtrain)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train accuracy score is:",accuracy_score(ytrain, predict_y))
predict_y = clf.predict(xcv)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation accuracy score is:",accuracy_score(ycv, predict_y))
# Out:
# for n_estimators = 50 and max depth =  5
#  True Negative = 11029
#  False positive = 680
#  False Negative = 819
#  True Positive = 8190
# for n_estimators = 50 and max depth =  10
#  True Negative = 11245
#  False positive = 464
#  False Negative = 573
#  True Positive = 8436
# for n_estimators = 100 and max depth =  5
#  True Negative = 11010
#  False positive = 699
#  False Negative = 886
#  True Positive = 8123
# for n_estimators = 100 and max depth =  10
#  True Negative = 11259
#  False positive = 450
#  False Negative = 603
#  True Positive = 8406
# for n_estimators = 150 and max depth =  5
#  True Negative = 11054
#  False positive = 655
#  False Negative = 901
#  True Positive = 8108
# for n_estimators = 150 and max depth =  10
#  True Negative = 11266
#  False positive = 443
#  False Negative = 611
#  True Positive = 8398
# for n_estimators = 200 and max depth =  5
#  True Negative = 11041
#  False positive = 668
#  False Negative = 842
#  True Positive = 8167
# ...

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(xtr,ytr)
pred = clf.predict(xtest) 
accuracy_array.append(accuracy_score(ytest, pred))
df_cm = confusion_matrix(ytest,pred)
cm(df_cm)
predict_y = clf.predict(xtest)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test accuracy score is:",accuracy_score(ytest, predict_y))
# Out:
#  True Negative = 13965
#  False positive = 709
#  False Negative = 781
#  True Positive = 10443
# For values of best estimator =  50 The test accuracy score is: 0.9424665997374314

# %% [markdown]
# ## For Random Forest Classifier :
# ##### Train Accuracy : 94.92% <br>
# ##### Cross Validation Accuracy : 94.75% <br>
# ##### Test Accuracy : 94.24% <br>

# %%
for name, importance in zip(df2, clf.feature_importances_):
    print(name, "=", importance)
# Out:
# FDistance = 0.016637462399032184
# Inflight_wifi_service = 0.15318887242833745
# DA_time_conv = 0.00987058363398679
# Ease = 0.03886573286906764
# Food_and_drink = 0.008736331777670964
# Online_boarding = 0.23580834729520223
# Seat_comfort = 0.05278028757897103
# Inflight_entertainment = 0.08252849517135485
# Onboard_service = 0.04150114231786265
# Leg_room_service = 0.04926153932230504
# Baggage_handling = 0.017389432755521645
# Checkin_service = 0.014876454931635443
# Inflight_service = 0.016382399788032544
# Cleanliness = 0.025132328106328882
# binned = 0.008840269917349968
# loy = 0.05140787391668526
# tt = 0.1767924457906555

# %%
features = df2.columns.values
importances = clf.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# Now I've displayed the relative importance of features.

# %% [markdown]
# # Gradient Boosting Classifier

# %%
alpha = [50,100,150,200,250,300,350,400]
max_depth = [5, 10]
accuracy_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = GradientBoostingClassifier(n_estimators=i, max_depth=j)
        clf.fit(xtrain,ytrain)
        #sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        #sig_clf.fit(X_train_,y_train_)
        pred = clf.predict(xcv) 
        #sig_clf_probs = sig_clf.predict_proba(X_cv_)
        accuracy_array.append(accuracy_score(ycv, pred))
        df_cm = confusion_matrix(ycv,pred)
        cm(df_cm)
# Out:
# for n_estimators = 50 and max depth =  5
#  True Negative = 11326
#  False positive = 383
#  False Negative = 681
#  True Positive = 8328
# for n_estimators = 50 and max depth =  10
#  True Negative = 11440
#  False positive = 269
#  False Negative = 532
#  True Positive = 8477
# for n_estimators = 100 and max depth =  5
#  True Negative = 11399
#  False positive = 310
#  False Negative = 572
#  True Positive = 8437
# for n_estimators = 100 and max depth =  10
#  True Negative = 11437
#  False positive = 272
#  False Negative = 514
#  True Positive = 8495
# for n_estimators = 150 and max depth =  5
#  True Negative = 11420
#  False positive = 289
#  False Negative = 549
#  True Positive = 8460
# for n_estimators = 150 and max depth =  10
#  True Negative = 11443
#  False positive = 266
#  False Negative = 501
#  True Positive = 8508
# for n_estimators = 200 and max depth =  5
#  True Negative = 11433
#  False positive = 276
#  False Negative = 538
#  True Positive = 8471
# ...

# %%
print(accuracy_array)
best_alpha = np.argmax(accuracy_array)
clf = GradientBoostingClassifier(n_estimators=alpha[int(best_alpha/2)],max_depth=max_depth[int(best_alpha%2)])
clf.fit(xtrain,ytrain)


predict_y = clf.predict(xtrain)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train accuracy score is:",accuracy_score(ytrain, predict_y))
predict_y = clf.predict(xcv)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation accuracy score is:",accuracy_score(ycv, predict_y))
# Out:
# [0.9486436914760112, 0.9613379669852302, 0.9574283231972198, 0.9620619750941211, 0.9595520803166329, 0.9629790520320495, 0.9607104932908582, 0.9620619750941211, 0.9612896997779709, 0.9626411815812337, 0.9615310358142678, 0.9633651896901245, 0.9616758374360459, 0.9630755864465682, 0.9616758374360459, 0.9627377159957525]
# For values of best estimator =  300 The train accuracy score is: 0.999963799157727
# For values of best estimator =  300 The cross validation accuracy score is: 0.96293078482479

# %%
clf = GradientBoostingClassifier(n_estimators=alpha[int(best_alpha/2)], max_depth=max_depth[int(best_alpha%2)])
clf.fit(xtr,ytr)
pred = clf.predict(xtest) 
accuracy_array.append(accuracy_score(ytest, pred))
df_cm = confusion_matrix(ytest,pred)
cm(df_cm)
predict_y = clf.predict(xtest)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test accuracy score is:",accuracy_score(ytest, predict_y))
# Out:
#  True Negative = 14287
#  False positive = 387
#  False Negative = 640
#  True Positive = 10584
# For values of best estimator =  300 The test accuracy score is: 0.9603444281411692

# %% [markdown]
# # For Gradient Boosting Classifier :
# ##### Train Accuracy : 99.99%
# ##### Cross Validation Accuracy : 96.29%
# ##### Test Accuracy : 96.03%

# %% [markdown]
# # Ensemble Voting Classifier

# %%
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions
import itertools

# %%
clf1 = RandomForestClassifier(n_estimators=100, max_depth=10)
clf2 = GradientBoostingClassifier(n_estimators=400, max_depth=5)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2],voting='soft')
eclf.fit(xtrain,ytrain)
        #sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        #sig_clf.fit(X_train_,y_train_)
pred = eclf.predict(xcv) 
        #sig_clf_probs = sig_clf.predict_proba(X_cv_)
accuracy_array.append(accuracy_score(ycv, pred))
df_cm = confusion_matrix(ycv,pred)
cm(df_cm)
# Out:
# C:\ProgramData\Anaconda31\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#  True Negative = 11395
#  False positive = 314
#  False Negative = 513
#  True Positive = 8496

# %%
print(accuracy_array)
eclf.fit(xtrain,ytrain)


predict_y = eclf.predict(xtrain)
print('For values of best estimator,The train accuracy score is:',accuracy_score(ytrain, predict_y))
predict_y = eclf.predict(xcv)
print('For values of best estimator ,The cross validation accuracy score is:',accuracy_score(ycv, predict_y))
# Out:
# [0.9486436914760112, 0.9613379669852302, 0.9574283231972198, 0.9620619750941211, 0.9595520803166329, 0.9629790520320495, 0.9607104932908582, 0.9620619750941211, 0.9612896997779709, 0.9626411815812337, 0.9615310358142678, 0.9633651896901245, 0.9616758374360459, 0.9630755864465682, 0.9616758374360459, 0.9627377159957525, 0.9603444281411692, 0.9600830195964861]
# C:\ProgramData\Anaconda31\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# For values of best estimator,The train accuracy score is: 0.9656212667881406
# For values of best estimator ,The cross validation accuracy score is: 0.9601312868037455
# ...

# %%
eclf.fit(xtr,ytr)
pred = eclf.predict(xtest) 
accuracy_array.append(accuracy_score(ytest, pred))
df_cm = confusion_matrix(ytest,pred)
cm(df_cm)
predict_y = eclf.predict(xtest)
print('For values of best estimator The test accuracy score is:',accuracy_score(ytest, predict_y))
# Out:
# C:\ProgramData\Anaconda31\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#  True Negative = 14289
#  False positive = 385
#  False Negative = 664
#  True Positive = 10560
# For values of best estimator The test accuracy score is: 0.9594949416943394
# C:\ProgramData\Anaconda31\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# # For Ensemble Vote Classifier :
# ##### Train Accuracy: 96.56%
# ##### Cross Validation Accuracy : 96.01%
# ##### Test Accuracy : 95.94%

# %% [markdown]
# # Conclusion:
# 1.Based on the fine tuning of hyper-parameters, the system gives an accuracy around 96% . <br>
# 2.The Feature Engineering part is one of the most important steps while solving this problem,<br>
# on performing which the accuracy increased from 94% to 96%.
